# %% [markdown]
# ### MapBox Plot

# %%
from pathlib import Path
import pandas as pd
import os
import plotly.express as px

# %%
map_box_api = os.getenv("MAPBOX_API_KEY")
px.set_mapbox_access_token(map_box_api)

# %%
map_df = pd.read_csv(Path('Resources/us_map_data.csv'), index_col=0)

# %%
confortability_income_2019 = confortability_income['2019']

# %%
map_df['Unemployment Rate'] = round(map_df['Unemployment Rate'], 2)

# %%
map_df
# Out:
#              State        Year  Confortability Income Threshold  \
# 0          Alabama  12/31/2020                            55066
# 1           Alaska  12/31/2020                            59327
# 2          Arizona  12/31/2020                            51866
# 3         Arkansas  12/31/2020                            46681
# 4       California  12/31/2020                            48480
# ..             ...         ...                              ...
# 495       Virginia  12/31/2029                            48503
# 496     Washington  12/31/2029                            48478
# 497  West Virginia  12/31/2029                            42912
# 498      Wisconsin  12/31/2029                            41689
# 499        Wyoming  12/31/2029                            42953
#
#      Poverty Income Threshold  Rent Per State  Unemployment Rate   Latitude  \
# 0                       25884            1169               2.92  32.806671
# ...

# %%
fig= px.scatter_mapbox(map_df, color = 'State', size = 'Unemployment Rate', 
                      lon ='Longitude', lat='Latitude', hover_name ='State', 
                      center={'lat':38.5,'lon':-97.5}, zoom = 3, 
                      width = 900, height = 500, animation_frame = 'Year'
                      )

#fig.update_layout(transition = {'duration': 100000000000000000})

# %%
#fig
